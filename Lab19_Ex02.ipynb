// %% [markdown]
// # Lab 19 Exercise 2

// %% [markdown]
// ## Delegate on instance and static method

// %% [markdown]
// 1.สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab19_Ex02
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// var im = new InstanceMethod();
// MyDelegate del = im.MethodA;
// del("Hello World");
// del = StaticMethod.MethodB;
// del("Hello Moon");
//
// class InstanceMethod
// {
//      public void MethodA(string message)
//      {
//         System.Console.WriteLine($"You are calling instance MethodA() with message {message}");
//      }
// }
// static class StaticMethod
// {
//      public static void MethodB(string message)
//      {
//         System.Console.WriteLine($"You are calling static MethodB() with message {message}");
//      }
// }
//
// public delegate void MyDelegate(string message);
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab19_Ex02
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab19_Ex02
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// Instance method สามารถใช้กับ delegate ได้โดยอ้างอิงผ่าน object instance (im.MethodA)
//
// Static method สามารถใช้กับ delegate ได้ แต่ต้องอ้างอิงผ่านชื่อคลาส (StaticMethod.MethodB)
//
// Static class (StaticMethod) ไม่สามารถถูกใช้เป็นตัวแปร delegate ได้โดยตรง แต่สามารถอ้างอิง method ที่เป็น static ได้

// %% [markdown]
// # Lab 19 Exercise 10

// %% [markdown]
// ## Func

// %% [markdown]
// 1.สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab19_Ex10
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// // Func
// Func<int, int, int> add = Add;
// int a = 5, b= 9;
// int c = add(a,b);
// System.Console.WriteLine($"Add({a}, {b}) return {c}");
//
// Func <string, string> convertToUpper = s => s.ToUpper();
// string before = "all Lowercase characters";
// System.Console.WriteLine($"Before = \"{before}\", after = \"{convertToUpper(before)}\"");
//
// static int Add(int a, int b)
// {
//     return a + b;
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab19_Ex10
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab19_Ex10
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// Func สามารถกำหนดประเภทของพารามิเตอร์และประเภทของค่าที่คืนได้
//
// การใช้ Func ทำให้โค้ดมีความอ่านง่ายและสามารถนำฟังก์ชันไปใช้ซ้ำได้ในหลายๆ จุด
//
// Func ช่วยให้สามารถใช้งานฟังก์ชันเป็นตัวแปรในรูปแบบของการคำนวณหรือการประมวลผล
